# %% [markdown]
# <a href="https://colab.research.google.com/github/achiever117/Customer-Churn-prediction-using-ANN/blob/main/customer_churn_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
df=pd.read_csv("/Churn_Modelling.csv")

# %%
df.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
# visualizing continuous variables

fig, ax = plt.subplots(2, 2, figsize = (16, 10))

sns.boxplot(x = 'Exited', y = 'CreditScore', data = df, ax = ax[0][0])
sns.boxplot(x = 'Exited', y = 'Age', data = df, ax = ax[0][1])
sns.boxplot(x = 'Exited', y = 'Balance', data = df, ax = ax[1][0])
sns.boxplot(x = 'Exited', y = 'EstimatedSalary', data = df, ax = ax[1][1])

plt.tight_layout()
plt.show()

# %%
df.drop(columns = ['RowNumber', 'CustomerId', 'Surname'], axis = 1, inplace = True)
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df.Geography.value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
# Encoding categorical variables

df['Geography'] = df['Geography'].map({'France' : 0, 'Germany' : 1, 'Spain' : 2})
df['Gender'] = df['Gender'].map({'Male' : 0, 'Female' : 1})

# %%
from tensorflow.keras.utils import to_categorical

X = df.drop('Exited', axis = 1)
y = to_categorical(df.Exited)

# %%
# splitting data into training set and test set

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
# Scaling data

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Building ANNs
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import BatchNormalization

# initializing ann
model = Sequential()

# adding the first input layer and the first hidden layer
model.add(Dense(10, kernel_initializer = 'normal', activation = 'relu', input_shape = (10, )))

# adding batch normalization and dropout layer
model.add(Dropout(rate = 0.1))
model.add(BatchNormalization())

# adding the third hidden layer
model.add(Dense(7, kernel_initializer = 'normal', activation = 'relu'))

# adding batch normalization and dropout layer
model.add(Dropout(rate = 0.1))
model.add(BatchNormalization())

# adding the output layer
model.add(Dense(2, kernel_initializer = 'normal', activation = 'sigmoid'))

# compiling the model
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# fitting the model to the training set

model_history = model.fit(X_train, y_train, validation_split = 0.20, validation_data = (X_test, y_test), epochs = 100)
# Out:
# Epoch 1/100
# 235/235 [==============================] - 5s 6ms/step - loss: 0.5991 - accuracy: 0.7375 - val_loss: 0.5315 - val_accuracy: 0.7948
# Epoch 2/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.4322 - accuracy: 0.8248 - val_loss: 0.4092 - val_accuracy: 0.8088
# Epoch 3/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3880 - accuracy: 0.8377 - val_loss: 0.3590 - val_accuracy: 0.8512
# Epoch 4/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3889 - accuracy: 0.8367 - val_loss: 0.3564 - val_accuracy: 0.8556
# Epoch 5/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3789 - accuracy: 0.8417 - val_loss: 0.3583 - val_accuracy: 0.8584
# Epoch 6/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3777 - accuracy: 0.8392 - val_loss: 0.3510 - val_accuracy: 0.8524
# Epoch 7/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3782 - accuracy: 0.8435 - val_loss: 0.3470 - val_accuracy: 0.8600
# Epoch 8/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3773 - accuracy: 0.8437 - val_loss: 0.3509 - val_accuracy: 0.8592
# Epoch 9/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3752 - accuracy: 0.8421 - val_loss: 0.3494 - val_accuracy: 0.8596
# Epoch 10/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3774 - accuracy: 0.8428 - val_loss: 0.3483 - val_accuracy: 0.8616
# Epoch 11/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3752 - accuracy: 0.8432 - val_loss: 0.3553 - val_accuracy: 0.8608
# Epoch 12/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3779 - accuracy: 0.8416 - val_loss: 0.3490 - val_accuracy: 0.8604
# Epoch 13/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3709 - accuracy: 0.8441 - val_loss: 0.3529 - val_accuracy: 0.8592
# Epoch 14/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3718 - accuracy: 0.8456 - val_loss: 0.3546 - val_accuracy: 0.8576
# Epoch 15/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3744 - accuracy: 0.8457 - val_loss: 0.3524 - val_accuracy: 0.8620
# Epoch 16/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3687 - accuracy: 0.8465 - val_loss: 0.3490 - val_accuracy: 0.8604
# Epoch 17/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3717 - accuracy: 0.8433 - val_loss: 0.3484 - val_accuracy: 0.8572
# Epoch 18/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3672 - accuracy: 0.8495 - val_loss: 0.3487 - val_accuracy: 0.8600
# Epoch 19/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3712 - accuracy: 0.8453 - val_loss: 0.3494 - val_accuracy: 0.8576
# Epoch 20/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3696 - accuracy: 0.8461 - val_loss: 0.3480 - val_accuracy: 0.8580
# Epoch 21/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3711 - accuracy: 0.8499 - val_loss: 0.3471 - val_accuracy: 0.8560
# Epoch 22/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3697 - accuracy: 0.8488 - val_loss: 0.3486 - val_accuracy: 0.8564
# Epoch 23/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3668 - accuracy: 0.8499 - val_loss: 0.3515 - val_accuracy: 0.8516
# Epoch 24/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3687 - accuracy: 0.8473 - val_loss: 0.3544 - val_accuracy: 0.8532
# Epoch 25/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3717 - accuracy: 0.8456 - val_loss: 0.3490 - val_accuracy: 0.8560
# Epoch 26/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3661 - accuracy: 0.8501 - val_loss: 0.3530 - val_accuracy: 0.8560
# Epoch 27/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3711 - accuracy: 0.8457 - val_loss: 0.3473 - val_accuracy: 0.8608
# Epoch 28/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3718 - accuracy: 0.8469 - val_loss: 0.3500 - val_accuracy: 0.8592
# Epoch 29/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3671 - accuracy: 0.8519 - val_loss: 0.3503 - val_accuracy: 0.8604
# Epoch 30/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3701 - accuracy: 0.8468 - val_loss: 0.3466 - val_accuracy: 0.8604
# Epoch 31/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3691 - accuracy: 0.8493 - val_loss: 0.3501 - val_accuracy: 0.8588
# Epoch 32/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3668 - accuracy: 0.8512 - val_loss: 0.3485 - val_accuracy: 0.8592
# Epoch 33/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3718 - accuracy: 0.8465 - val_loss: 0.3492 - val_accuracy: 0.8564
# Epoch 34/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3677 - accuracy: 0.8476 - val_loss: 0.3480 - val_accuracy: 0.8580
# Epoch 35/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3636 - accuracy: 0.8504 - val_loss: 0.3507 - val_accuracy: 0.8584
# Epoch 36/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3633 - accuracy: 0.8509 - val_loss: 0.3495 - val_accuracy: 0.8584
# Epoch 37/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3660 - accuracy: 0.8500 - val_loss: 0.3540 - val_accuracy: 0.8600
# Epoch 38/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3644 - accuracy: 0.8488 - val_loss: 0.3518 - val_accuracy: 0.8580
# Epoch 39/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3662 - accuracy: 0.8520 - val_loss: 0.3525 - val_accuracy: 0.8560
# Epoch 40/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3632 - accuracy: 0.8493 - val_loss: 0.3517 - val_accuracy: 0.8548
# Epoch 41/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3632 - accuracy: 0.8508 - val_loss: 0.3506 - val_accuracy: 0.8568
# Epoch 42/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3657 - accuracy: 0.8516 - val_loss: 0.3484 - val_accuracy: 0.8556
# Epoch 43/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3655 - accuracy: 0.8468 - val_loss: 0.3485 - val_accuracy: 0.8572
# Epoch 44/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3655 - accuracy: 0.8500 - val_loss: 0.3502 - val_accuracy: 0.8572
# Epoch 45/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3634 - accuracy: 0.8512 - val_loss: 0.3514 - val_accuracy: 0.8572
# Epoch 46/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3656 - accuracy: 0.8496 - val_loss: 0.3518 - val_accuracy: 0.8580
# Epoch 47/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3619 - accuracy: 0.8489 - val_loss: 0.3495 - val_accuracy: 0.8572
# Epoch 48/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3688 - accuracy: 0.8479 - val_loss: 0.3504 - val_accuracy: 0.8584
# Epoch 49/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3697 - accuracy: 0.8483 - val_loss: 0.3512 - val_accuracy: 0.8576
# Epoch 50/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3667 - accuracy: 0.8485 - val_loss: 0.3483 - val_accuracy: 0.8556
# Epoch 51/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3677 - accuracy: 0.8485 - val_loss: 0.3509 - val_accuracy: 0.8584
# Epoch 52/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3652 - accuracy: 0.8493 - val_loss: 0.3454 - val_accuracy: 0.8584
# Epoch 53/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3697 - accuracy: 0.8456 - val_loss: 0.3458 - val_accuracy: 0.8560
# Epoch 54/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3671 - accuracy: 0.8519 - val_loss: 0.3489 - val_accuracy: 0.8564
# Epoch 55/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3674 - accuracy: 0.8481 - val_loss: 0.3508 - val_accuracy: 0.8576
# Epoch 56/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3652 - accuracy: 0.8497 - val_loss: 0.3490 - val_accuracy: 0.8564
# Epoch 57/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3644 - accuracy: 0.8509 - val_loss: 0.3506 - val_accuracy: 0.8548
# Epoch 58/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3653 - accuracy: 0.8483 - val_loss: 0.3457 - val_accuracy: 0.8560
# Epoch 59/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3668 - accuracy: 0.8497 - val_loss: 0.3520 - val_accuracy: 0.8584
# Epoch 60/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3656 - accuracy: 0.8469 - val_loss: 0.3461 - val_accuracy: 0.8592
# Epoch 61/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3629 - accuracy: 0.8524 - val_loss: 0.3503 - val_accuracy: 0.8588
# Epoch 62/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3608 - accuracy: 0.8551 - val_loss: 0.3488 - val_accuracy: 0.8540
# Epoch 63/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3638 - accuracy: 0.8503 - val_loss: 0.3526 - val_accuracy: 0.8528
# Epoch 64/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3666 - accuracy: 0.8520 - val_loss: 0.3489 - val_accuracy: 0.8572
# Epoch 65/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3661 - accuracy: 0.8493 - val_loss: 0.3469 - val_accuracy: 0.8560
# Epoch 66/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3628 - accuracy: 0.8492 - val_loss: 0.3581 - val_accuracy: 0.8512
# Epoch 67/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3660 - accuracy: 0.8516 - val_loss: 0.3480 - val_accuracy: 0.8548
# Epoch 68/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.3653 - accuracy: 0.8496 - val_loss: 0.3503 - val_accuracy: 0.8592
# Epoch 69/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.3642 - accuracy: 0.8520 - val_loss: 0.3507 - val_accuracy: 0.8572
# Epoch 70/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3635 - accuracy: 0.8519 - val_loss: 0.3491 - val_accuracy: 0.8568
# Epoch 71/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3630 - accuracy: 0.8519 - val_loss: 0.3487 - val_accuracy: 0.8584
# Epoch 72/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3648 - accuracy: 0.8479 - val_loss: 0.3473 - val_accuracy: 0.8572
# Epoch 73/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3663 - accuracy: 0.8515 - val_loss: 0.3493 - val_accuracy: 0.8584
# Epoch 74/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3609 - accuracy: 0.8531 - val_loss: 0.3458 - val_accuracy: 0.8596
# Epoch 75/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3623 - accuracy: 0.8532 - val_loss: 0.3492 - val_accuracy: 0.8560
# Epoch 76/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3598 - accuracy: 0.8517 - val_loss: 0.3474 - val_accuracy: 0.8564
# Epoch 77/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3620 - accuracy: 0.8495 - val_loss: 0.3518 - val_accuracy: 0.8572
# Epoch 78/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3670 - accuracy: 0.8507 - val_loss: 0.3524 - val_accuracy: 0.8572
# Epoch 79/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3659 - accuracy: 0.8508 - val_loss: 0.3503 - val_accuracy: 0.8560
# Epoch 80/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3606 - accuracy: 0.8489 - val_loss: 0.3505 - val_accuracy: 0.8564
# Epoch 81/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3661 - accuracy: 0.8496 - val_loss: 0.3470 - val_accuracy: 0.8556
# Epoch 82/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3649 - accuracy: 0.8509 - val_loss: 0.3544 - val_accuracy: 0.8544
# Epoch 83/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3654 - accuracy: 0.8509 - val_loss: 0.3503 - val_accuracy: 0.8596
# Epoch 84/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3660 - accuracy: 0.8501 - val_loss: 0.3460 - val_accuracy: 0.8600
# Epoch 85/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3629 - accuracy: 0.8508 - val_loss: 0.3470 - val_accuracy: 0.8584
# Epoch 86/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3619 - accuracy: 0.8519 - val_loss: 0.3489 - val_accuracy: 0.8568
# Epoch 87/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3642 - accuracy: 0.8488 - val_loss: 0.3512 - val_accuracy: 0.8548
# Epoch 88/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3662 - accuracy: 0.8501 - val_loss: 0.3469 - val_accuracy: 0.8560
# Epoch 89/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3629 - accuracy: 0.8493 - val_loss: 0.3525 - val_accuracy: 0.8516
# Epoch 90/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3626 - accuracy: 0.8513 - val_loss: 0.3490 - val_accuracy: 0.8576
# Epoch 91/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3655 - accuracy: 0.8516 - val_loss: 0.3504 - val_accuracy: 0.8540
# Epoch 92/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3653 - accuracy: 0.8533 - val_loss: 0.3493 - val_accuracy: 0.8564
# Epoch 93/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3649 - accuracy: 0.8541 - val_loss: 0.3488 - val_accuracy: 0.8576
# Epoch 94/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3647 - accuracy: 0.8528 - val_loss: 0.3519 - val_accuracy: 0.8556
# Epoch 95/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3652 - accuracy: 0.8480 - val_loss: 0.3495 - val_accuracy: 0.8508
# Epoch 96/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3608 - accuracy: 0.8547 - val_loss: 0.3491 - val_accuracy: 0.8520
# Epoch 97/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3623 - accuracy: 0.8515 - val_loss: 0.3483 - val_accuracy: 0.8596
# Epoch 98/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3652 - accuracy: 0.8520 - val_loss: 0.3478 - val_accuracy: 0.8584
# Epoch 99/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3676 - accuracy: 0.8472 - val_loss: 0.3511 - val_accuracy: 0.8584
# Epoch 100/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3613 - accuracy: 0.8529 - val_loss: 0.3489 - val_accuracy: 0.8556

# %%
acc = model.evaluate(X_test, y_test)[1]

print(f'Accuracy of model is {acc}')
# Out:
# 79/79 [==============================] - 0s 4ms/step - loss: 0.3489 - accuracy: 0.8556
# Accuracy of model is 0.8555999994277954

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                110
#
#  dropout (Dropout)           (None, 10)                0
#
#  batch_normalization (Batch  (None, 10)                40
#  Normalization)
#
#  dense_1 (Dense)             (None, 7)                 77
#
#  dropout_1 (Dropout)         (None, 7)                 0
#
#  batch_normalization_1 (Bat  (None, 7)                 28
#  chNormalization)
#
#  dense_2 (Dense)             (None, 2)                 16
#
# =================================================================
# Total params: 271 (1.06 KB)
# Trainable params: 237 (948.00 Byte)
# Non-trainable params: 34 (136.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, show_shapes = True)
